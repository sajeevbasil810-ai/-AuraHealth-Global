# %% [markdown]
# <a href="https://colab.research.google.com/github/sajeevbasil810-ai/-AuraHealth-Global/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>AURAHEALTH GLOBAL | BRICS Enterprise</title>
#   <style>
#     :root {
#       --bg-base: #040814;
#       --surface: #0B1221;
#       --surface-border: rgba(255, 255, 255, 0.08);
#       --primary: #06B6D4;
#       --primary-glow: rgba(6, 182, 212, 0.3);
#       --danger: #EF4444;
#       --warning: #F59E0B;
#       --success: #10B981;
#       --text-main: #F8FAFC;
#       --text-muted: #94A3B8;
#     }
#
#     * { box-sizing: border-box; margin: 0; padding: 0; font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Helvetica, Arial, sans-serif; }
#     body { background-color: var(--bg-base); color: var(--text-main); padding: 24px; display: flex; flex-direction: column; gap: 24px; min-height: 100vh; }
#
#     /* Header & Branding */
#     header { display: flex; justify-content: space-between; align-items: center; padding: 18px 24px; background: var(--surface); border: 1px solid var(--surface-border); border-radius: 16px; box-shadow: 0 8px 32px rgba(0,0,0,0.4); }
#     .brand-wrap { display: flex; align-items: center; gap: 14px; }
#     .brand-logo { width: 48px; height: 48px; background: linear-gradient(135deg, #06B6D4, #2563EB); border-radius: 12px; display: flex; align-items: center; justify-content: center; font-size: 24px; font-weight: 900; color: white; box-shadow: 0 0 20px var(--primary-glow); }
#     .brand-text h1 { font-size: 22px; font-weight: 800; letter-spacing: 0.5px; }
#     .brand-text h1 span { color: var(--primary); }
#     .brand-text p { font-size: 12px; color: var(--text-muted); font-weight: 500; margin-top: 4px; }
#     .enc-tag { font-size: 9px; background: rgba(16, 185, 129, 0.1); color: #10B981; padding: 2px 6px; border-radius: 4px; border: 1px solid rgba(16, 185, 129, 0.2); margin-left: 8px; text-transform: uppercase; letter-spacing: 1px; }
#
#     /* International Controls */
#     .controls-wrap { display: flex; align-items: center; gap: 12px; flex-wrap: wrap; }
#     select.lang-selector { background: #1E293B; color: #F8FAFC; border: 1px solid #334155; padding: 10px 16px; border-radius: 10px; font-size: 13px; font-weight: 600; cursor: pointer; outline: none; transition: 0.2s; }
#     select.lang-selector:hover { border-color: var(--primary); }
#     select.lang-selector optgroup { background: #0F172A; color: var(--text-muted); font-weight: bold; }
#     select.lang-selector option { color: #F8FAFC; font-weight: normal; }
#
#     .util-btn { background: rgba(6, 182, 212, 0.1); border: 1px solid var(--primary); color: #38BDF8; padding: 10px 20px; border-radius: 10px; font-size: 13px; font-weight: 700; cursor: pointer; display: flex; align-items: center; gap: 8px; transition: 0.3s; }
#     .util-btn:hover { background: rgba(6, 182, 212, 0.25); box-shadow: 0 0 15px var(--primary-glow); transform: translateY(-1px); }
#
#     /* Metrics Grid */
#     .metrics-bar { display: grid; grid-template-columns: repeat(auto-fit, minmax(220px, 1fr)); gap: 16px; }
#     .metric-card { background: var(--surface); border: 1px solid var(--surface-border); padding: 20px; border-radius: 14px; position: relative; overflow: hidden; }
#     .metric-card::before { content: ''; position: absolute; top: 0; left: 0; width: 4px; height: 100%; background: #334155; }
#     .metric-card.success::before { background: var(--success); }
#     .metric-card.danger::before { background: var(--danger); box-shadow: 0 0 10px rgba(239, 68, 68, 0.5); }
#     .metric-title { font-size: 11px; text-transform: uppercase; color: var(--text-muted); font-weight: 700; letter-spacing: 0.5px; margin-left: 8px; }
#     .metric-value { font-size: 26px; font-weight: 800; margin-top: 8px; margin-left: 8px; }
#
#     /* Main Dashboard Area */
#     .dashboard-grid { display: grid; grid-template-columns: 2fr 1fr; gap: 24px; }
#     @media (max-width: 1024px) { .dashboard-grid { grid-template-columns: 1fr; } }
#
#     .panel { background: var(--surface); border: 1px solid var(--surface-border); border-radius: 16px; padding: 24px; overflow-x: auto; }
#     .panel-header { display: flex; justify-content: space-between; align-items: center; margin-bottom: 20px; border-bottom: 1px solid #1E293B; padding-bottom: 12px; }
#     .panel-header h2 { font-size: 18px; font-weight: 700; }
#
#     /* Table */
#     table { width: 100%; border-collapse: collapse; text-align: left; font-size: 13px; white-space: nowrap; }
#     th { color: var(--text-muted); padding: 12px 16px; font-size: 11px; text-transform: uppercase; letter-spacing: 0.5px; border-bottom: 2px solid #1E293B; }
#     td { padding: 16px; border-bottom: 1px solid #1E293B; font-weight: 500; }
#     .tag-danger { background: rgba(239, 68, 68, 0.15); color: #FCA5A5; padding: 6px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; border: 1px solid rgba(239, 68, 68, 0.3); }
#     .tag-success { background: rgba(16, 185, 129, 0.15); color: #6EE7B7; padding: 6px 12px; border-radius: 20px; font-size: 11px; font-weight: 700; border: 1px solid rgba(16, 185, 129, 0.3); }
#
#     /* AI Box */
#     .ai-box { border-color: rgba(6, 182, 212, 0.3); box-shadow: inset 0 0 20px rgba(6, 182, 212, 0.05); }
#     .directive-card { background: rgba(239, 68, 68, 0.05); border-left: 4px solid var(--danger); padding: 16px; border-radius: 8px; margin-bottom: 16px; }
#     .directive-card.warning-card { background: rgba(245, 158, 11, 0.05); border-left-color: var(--warning); }
#     .directive-card h4 { font-size: 13px; color: #FCA5A5; font-weight: 700; }
#     .directive-card.warning-card h4 { color: #FCD34D; }
#     .directive-card p { font-size: 12px; color: #CBD5E1; margin-top: 6px; line-height: 1.5; }
#     .directive-action { color: var(--primary); font-size: 12px; font-weight: 700; margin-top: 10px; background: rgba(6, 182, 212, 0.1); padding: 8px; border-radius: 6px; }
#
#     .action-btn { background: linear-gradient(135deg, #06B6D4, #2563EB); color: white; border: none; padding: 16px; border-radius: 12px; font-weight: 800; font-size: 13px; cursor: pointer; width: 100%; margin-top: 10px; transition: 0.3s; text-transform: uppercase; letter-spacing: 1px; }
#     .action-btn:hover { box-shadow: 0 10px 25px rgba(6, 182, 212, 0.4); transform: translateY(-2px); }
#   </style>
# </head>
# <body>
#
#   <header>
#     <div class="brand-wrap">
#       <div class="brand-logo">✚</div>
#       <div class="brand-text">
#         <h1 style="display:flex; align-items:center;">AURA<span>HEALTH</span> GLOBAL <span class="enc-tag">AES-256 Encrypted</span></h1>
#         <p id="ui_sub">Track 3: BRICS Healthcare Supply Chain Resilience</p>
#       </div>
#     </div>
#     <div class="controls-wrap">
#       <select id="langSelector" class="lang-selector" onchange="updateLanguage()">
#         <optgroup label="🌐 Global Standard">
#           <option value="en">English (Global)</option>
#           <option value="es">Español (Spanish)</option>
#           <option value="fr">Français (French)</option>
#           <option value="ar">العربية (Arabic)</option>
#         </optgroup>
#         <optgroup label="🤝 BRICS Nations">
#           <option value="pt">Português (Brazil)</option>
#           <option value="ru">Русский (Russia)</option>
#           <option value="hi">हिन्दी (India - Hindi)</option>
#           <option value="zh">中文 (China - Mandarin)</option>
#         </optgroup>
#         <optgroup label="🇮🇳 Indian Regional">
#           <option value="ml">മലയാളം (Malayalam)</option>
#           <option value="ta">தமிழ் (Tamil)</option>
#           <option value="bn">বাংলা (Bengali)</option>
#         </optgroup>
#       </select>
#       <button class="util-btn" onclick="downloadReport()">📥 <span id="ui_dlBtn">Export CSV</span></button>
#       <button class="util-btn" onclick="playAudioAssist()">🔊 <span id="ui_vBtn">Audio Assist</span></button>
#     </div>
#   </header>
#
#   <div class="metrics-bar">
#     <div class="metric-card success">
#       <div class="metric-title" id="ui_m1t">Active Centers</div>
#       <div class="metric-value" style="color: var(--success);" id="ui_m1v">5 Nodes</div>
#     </div>
#     <div class="metric-card">
#       <div class="metric-title" id="ui_m2t">Medicine Pool</div>
#       <div class="metric-value" id="ui_m2v">1,440 Units</div>
#     </div>
#     <div class="metric-card danger">
#       <div class="metric-title" style="color: #FCA5A5;" id="ui_m3t">Stock-out Risk</div>
#       <div class="metric-value" style="color: #FCA5A5;" id="ui_m3v">2 Centers</div>
#     </div>
#     <div class="metric-card" style="border-color: rgba(245, 158, 11, 0.4);">
#       <div class="metric-title" style="color: #FCD34D;" id="ui_m4t">IoT Sensor Status</div>
#       <div class="metric-value" style="color: #FCD34D;" id="ui_m4v">1 Temp Warning</div>
#     </div>
#   </div>
#
#   <div class="dashboard-grid">
#     <div class="panel">
#       <div class="panel-header">
#         <h2 id="ui_thead">PHC Live Inventory & Telemetry Registry</h2>
#       </div>
#       <table>
#         <thead>
#           <tr>
#             <th id="th_1">Facility Node</th>
#             <th id="th_2">Stock (Paracetamol)</th>
#             <th id="th_4">Insulin Cold Chain (IoT)</th>
#             <th id="th_3">Status</th>
#           </tr>
#         </thead>
#         <tbody>
#           <tr>
#             <td><b>PHC Sector 1</b></td>
#             <td style="color: #FCA5A5;">75 Units</td>
#             <td style="color: #FCA5A5; font-weight: bold;">12°C ⚠️ (Alert)</td>
#             <td><span class="tag-danger" id="st_c1">Critical Risk</span></td>
#           </tr>
#           <tr>
#             <td><b>PHC Sector 2</b></td>
#             <td style="color: #FCA5A5;">85 Units</td>
#             <td style="color: #6EE7B7;">5°C ✅ (Safe)</td>
#             <td><span class="tag-danger" id="st_c2">Critical Risk</span></td>
#           </tr>
#           <tr>
#             <td><b>PHC Sector 3</b></td>
#             <td>520 Units</td>
#             <td style="color: #6EE7B7;">4°C ✅ (Safe)</td>
#             <td><span class="tag-success" id="st_s1">Surplus Node</span></td>
#           </tr>
#         </tbody>
#       </table>
#     </div>
#
#     <div class="panel ai-box">
#       <div class="panel-header">
#         <h2 style="color: var(--primary);" id="ui_aiHead">⚡ AI Autonomous Dispatch</h2>
#       </div>
#       <div class="directive-card">
#         <h4 id="al_h">🚨 Emergency Alert: Sector 1</h4>
#         <p id="al_d">Stock depletion expected within 24 hours.</p>
#         <div class="directive-action" id="al_a">💡 AI Action: Auto-routing 250 units from Sector 3.</div>
#       </div>
#       <div class="directive-card warning-card">
#         <h4 id="al_h2">⚠️ IoT Telemetry: Sector 1</h4>
#         <p id="al_d2">Hardware sensor detects cooling failure (>8°C). Insulin payload compromised.</p>
#         <div class="directive-action" id="al_a2">💡 AI Action: Dispatching emergency cold-storage unit.</div>
#       </div>
#       <button class="action-btn" id="ui_dBtn" onclick="alert('✅ Cryptographic redistribution & hardware recalibration command sent to grid.')">Authorize Dispatch</button>
#     </div>
#   </div>
#
#   <script>
#     const langDB = {
#       en: { code: "en-US", sub: "Track 3: BRICS Healthcare Supply Chain Resilience", vBtn: "Audio Assist", dlBtn: "Export CSV", m1t: "Active Centers", m1v: "5 Nodes", m2t: "Medicine Pool", m2v: "1,440 Units", m3t: "Stock-out Risk", m3v: "2 Centers", m4t: "IoT Sensor Status", m4v: "1 Temp Warning", th_head: "Live Inventory & Telemetry", th1: "Facility Node", th2: "Stock Level", th3: "Status", th4: "Cold Chain (IoT)", st_c: "Critical Risk", st_s: "Surplus Node", aiHead: "⚡ AI Autonomous Dispatch", al_h: "🚨 Emergency Alert: Sector 1", al_d: "Stock depletion expected within 24 hours.", al_a: "💡 AI Action: Auto-routing 250 units from Sector 3.", al_h2: "⚠️ IoT Telemetry: Sector 1", al_d2: "Sensor detects cooling failure (>8°C).", al_a2: "💡 AI Action: Dispatching emergency cold-storage.", dBtn: "AUTHORIZE DISPATCH", speech: "System Summary. Sector 1 faces critical stock shortages and an IoT hardware cooling failure. AI recommends immediate redistribution and dispatch of cold-storage units." },
#       es: { code: "es-ES", sub: "Pista 3: Resiliencia de la Cadena de Salud", vBtn: "Audio", dlBtn: "Exportar CSV", m1t: "Centros Activos", m1v: "5 Nodos", m2t: "Reserva Total", m2v: "1,440 Unid", m3t: "Riesgo de Agotamiento", m3v: "2 Centros", m4t: "Sensores IoT", m4v: "1 Alerta", th_head: "Inventario y Telemetría", th1: "Nodo", th2: "Stock", th3: "Estado", th4: "Cadena de Frío (IoT)", st_c: "Crítico", st_s: "Excedente", aiHead: "⚡ Despacho IA", al_h: "🚨 Alerta: Sector 1", al_d: "Agotamiento en 24 horas.", al_a: "💡 Acción: Enrutamiento de 250 unid.", al_h2: "⚠️ Telemetría IoT: Sector 1", al_d2: "Fallo de enfriamiento detectado.", al_a2: "💡 Acción: Despachando unidad de frío.", dBtn: "AUTORIZAR", speech: "Resumen del sistema. El Sector 1 enfrenta escasez y fallo de enfriamiento IoT. La IA despacha recursos de emergencia." },
#       ml: { code: "ml-IN", sub: "ട്രാക്ക് 3: ഹെൽത്ത്‌കെയർ സപ്ലൈ ചെയിൻ പ്ലാറ്റ്‌ഫോം", vBtn: "ഓഡിയോ അസിസ്റ്റ്", dlBtn: "റിപ്പോർട്ട് ഡൗൺലോഡ്", m1t: "സജീവ കേന്ദ്രങ്ങൾ", m1v: "5 നോഡുകൾ", m2t: "മൊത്തം ശേഖരം", m2v: "1,440 എണ്ണം", m3t: "ക്ഷാമ മുന്നറിയിപ്പ്", m3v: "2 കേന്ദ്രങ്ങൾ", m4t: "IoT സെൻസർ അവസ്ഥ", m4v: "1 താപനില അലേർട്ട്", th_head: "തത്സമയ വിവരങ്ങൾ & ടെലിമെട്രി", th1: "ആരോഗ്യകേന്ദ്രം", th2: "സ്റ്റോക്ക്", th3: "അവസ്ഥ", th4: "കോൾഡ് ചെയിൻ (IoT)", st_c: "ഗുരുതരം", st_s: "അധിക ശേഖരം", aiHead: "⚡ AI റീഡിസ്ട്രിബ്യൂഷൻ", al_h: "🚨 അടിയന്തര മുന്നറിയിപ്പ്: സെക്ടർ 1", al_d: "24 മണിക്കൂറിനുള്ളിൽ സ്റ്റോക്ക് തീരും.", al_a: "💡 AI നിർദ്ദേശം: 250 എണ്ണം ഉടൻ അയക്കുക.", al_h2: "⚠️ IoT അലേർട്ട്: സെക്ടർ 1", al_d2: "സെൻസറിൽ ഇൻസുലിൻ താപനില വർദ്ധനവ് (>8°C).", al_a2: "💡 AI നിർദ്ദേശം: എമർജൻസി കോൾഡ് യൂണിറ്റ് അയക്കുന്നു.", dBtn: "വിതരണം സാധൂകരിക്കുക", speech: "ഓറ ഹെൽത്ത് സിസ്റ്റം വിവരങ്ങൾ. സെക്ടർ ഒന്നിൽ മരുന്നുകൾ തീരാറായിരിക്കുന്നു, ഒപ്പം ഐ ഓ ടി സെൻസറിൽ താപനില വർദ്ധനവും രേഖപ്പെടുത്തി. പ്രതിരോധ നടപടികൾ ആരംഭിച്ചു." },
#       hi: { code: "hi-IN", sub: "ट्रैक 3: हेल्थकेयर आपूर्ति श्रृंखला", vBtn: "ऑडियो सहायता", dlBtn: "रिपोर्ट डाउनलोड", m1t: "सक्रिय केंद्र", m1v: "5 नोड्स", m2t: "दवा भंडार", m2v: "1,440 इकाइयां", m3t: "स्टॉक जोखिम", m3v: "2 केंद्र", m4t: "IoT सेंसर", m4v: "1 चेतावनी", th_head: "लाइव इन्वेंटरी", th1: "सुविधा", th2: "स्टॉक", th3: "स्थिति", th4: "कोल्ड चेन (IoT)", st_c: "गंभीर जोखिम", st_s: "अधिशेष", aiHead: "⚡ एआई प्रेषण", al_h: "🚨 अलर्ट: सेक्टर 1", al_d: "24 घंटे में स्टॉक समाप्त।", al_a: "💡 एआई कार्रवाई: 250 इकाइयां भेजें।", al_h2: "⚠️ IoT टेलीमेट्री", al_d2: "सेंसर शीतलन विफलता का पता लगाता है।", al_a2: "💡 एआई कार्रवाई: आपातकालीन शीत-भंडारण भेज रहा है।", dBtn: "अधिकृत करें", speech: "सिस्टम सारांश। सेक्टर 1 में गंभीर कमी और IoT शीतलन विफलता है। एआई तत्काल कार्रवाई कर रहा है।" },
#       fr: { code: "fr-FR", sub: "Piste 3 : Chaîne d'approvisionnement (BRICS)", vBtn: "Audio", dlBtn: "Exporter CSV", m1t: "Centres", m1v: "5 Nœuds", m2t: "Réserve", m2v: "1 440 Unités", m3t: "Risque de Rupture", m3v: "2 Centres", m4t: "Capteurs IoT", m4v: "1 Alerte", th_head: "Inventaire et Télémétrie", th1: "Centre", th2: "Stock", th3: "Statut", th4: "Chaîne du Froid (IoT)", st_c: "Critique", st_s: "Excédent", aiHead: "⚡ Répartition IA", al_h: "🚨 Alerte : Secteur 1", al_d: "Épuisement sous 24h.", al_a: "💡 Action IA : Routage de 250 unités.", al_h2: "⚠️ IoT Télémétrie", al_d2: "Panne de refroidissement (>8°C).", al_a2: "💡 Action IA : Envoi d'unité frigorifique.", dBtn: "AUTORISER", speech: "Le secteur 1 fait face à une pénurie et à une panne IoT. L'IA engage la procédure d'urgence." },
#       pt: { code: "pt-BR", sub: "Trilha 3: Resiliência da Cadeia BRICS", vBtn: "Voz", dlBtn: "Exportar CSV", m1t: "Centros", m1v: "5 Nós", m2t: "Reserva", m2v: "1.440 Unid", m3t: "Risco", m3v: "2 Centros", m4t: "Sensores IoT", m4v: "1 Alerta", th_head: "Inventário e Telemetria", th1: "Unidade", th2: "Estoque", th3: "Status", th4: "Cadeia de Frio (IoT)", st_c: "Crítico", st_s: "Superávit", aiHead: "⚡ Despacho IA", al_h: "🚨 Alerta: Setor 1", al_d: "Esgotamento em 24h.", al_a: "💡 Ação: Enviar 250 unid.", al_h2: "⚠️ IoT Telemetria", al_d2: "Falha de resfriamento (>8°C).", al_a2: "💡 Ação: Enviando armazenamento frio.", dBtn: "AUTORIZAR", speech: "O Setor 1 enfrenta escassez e falha IoT. Inteligência artificial em ação." },
#       ru: { code: "ru-RU", sub: "Трек 3: Цепочка поставок БРИКС", vBtn: "Аудио", dlBtn: "Экспорт CSV", m1t: "Центры", m1v: "5 узлов", m2t: "Резерв", m2v: "1,440 ед.", m3t: "Риск", m3v: "2 центра", m4t: "Датчики IoT", m4v: "1 Алерт", th_head: "Инвентарь и Телеметрия", th1: "Узел", th2: "Запасы", th3: "Статус", th4: "Холодовая Цепь (IoT)", st_c: "Критически", st_s: "Профицит", aiHead: "⚡ ИИ Авто-распределение", al_h: "🚨 Алерт: Сектор 1", al_d: "Истощение за 24ч.", al_a: "💡 Действие: Маршрутизация 250 ед.", al_h2: "⚠️ Телеметрия IoT", al_d2: "Сбой охлаждения (>8°C).", al_a2: "💡 Действие: Отправка холодильной камеры.", dBtn: "АВТОРИЗОВАТЬ", speech: "Сектор 1 сталкивается с дефицитом и сбоем IoT. ИИ отправляет ресурсы." },
#       zh: { code: "zh-CN", sub: "赛道 3：金砖国家医疗供应链", vBtn: "语音助手", dlBtn: "导出报告", m1t: "活跃中心", m1v: "5个节点", m2t: "药品储备", m2v: "1,440", m3t: "缺货风险", m3v: "2个", m4t: "IoT传感器", m4v: "1 警告", th_head: "实时库存与遥测", th1: "节点", th2: "库存", th3: "状态", th4: "冷链 (IoT)", st_c: "严重", st_s: "充足", aiHead: "⚡ AI 调度", al_h: "🚨 警告：第1区", al_d: "24小时内耗尽。", al_a: "💡 AI 建议：分配250单位。", al_h2: "⚠️ IoT 遥测", al_d2: "传感器检测到冷却失效(>8°C)。", al_a2: "💡 AI建议：派遣冷链车。", dBtn: "授权调度", speech: "第1区面临缺货和IoT冷却故障，AI已启动紧急响应。" },
#       ta: { code: "ta-IN", sub: "பாதை 3: சுகாதார விநியோக சங்கிலி", vBtn: "குரல் உதவி", dlBtn: "அறிக்கை", m1t: "மையங்கள்", m1v: "5", m2t: "மருந்து", m2v: "1,440", m3t: "அபாயம்", m3v: "2", m4t: "IoT சென்சார்", m4v: "1 எச்சரிக்கை", th_head: "நேரடி இருப்பு", th1: "மையம்", th2: "இருப்பு", th3: "நிலை", th4: "குளிர் சங்கிலி (IoT)", st_c: "ஆபத்து", st_s: "உபரி", aiHead: "⚡ AI பகிர்தல்", al_h: "🚨 எச்சரிக்கை: பிரிவு 1", al_d: "24 மணிநேரத்தில் தீர்ந்துவிடும்.", al_a: "💡 AI செயல்: 250 அலகுகள்.", al_h2: "⚠️ IoT எச்சரிக்கை", al_d2: "குளிர்ச்சி தோல்வி (>8°C).", al_a2: "💡 AI செயல்: உறைவிப்பான் அனுப்பப்படுகிறது.", dBtn: "அனுமதி", speech: "பிரிவு 1-இல் மருந்து பற்றாக்குறை மற்றும் சென்சார் கோளாறு. AI நடவடிக்கை எடுக்கிறது." },
#       bn: { code: "bn-IN", sub: "ট্র্যাক 3: ব্রিকস হেলথকেয়ার", vBtn: "ভয়েস", dlBtn: "রিপোর্ট", m1t: "সক্রিয় কেন্দ্র", m1v: "৫", m2t: "মজুত", m2v: "১,৪৪০", m3t: "ঝুঁকি", m3v: "২", m4t: "IoT সেন্সর", m4v: "১ সতর্কতা", th_head: "লাইভ ইনভেন্টরি", th1: "কেন্দ্র", th2: "স্টক", th3: "অবস্থা", th4: "কোল্ড চেইন (IoT)", st_c: "জটিল", st_s: "উদ্বৃত্ত", aiHead: "⚡ এআই প্রেরণ", al_h: "🚨 সতর্কতা: সেক্টর 1", al_d: "২৪ ঘন্টায় শেষ।", al_a: "💡 এআই অ্যাকশন: ২৫০ ইউনিট।", al_h2: "⚠️ IoT টেলিমেট্রি", al_d2: "কুলিং ব্যর্থতা (>8°C)।", al_a2: "💡 অ্যাকশন: কোল্ড-স্টোরেজ পাঠানো হচ্ছে।", dBtn: "অনুমোদন", speech: "সেক্টর 1 এ স্টক শেষ এবং IoT ত্রুটি। এআই ব্যবস্থা নিচ্ছে।" },
#       ar: { code: "ar-SA", sub: "المسار 3: سلسلة إمداد الرعاية", vBtn: "مساعد صوتي", dlBtn: "تصدير", m1t: "المراكز", m1v: "5", m2t: "المخزون", m2v: "1,440", m3t: "الخطر", m3v: "2", m4t: "مستشعر IoT", m4v: "تحذير 1", th_head: "المخزون والقياس المباشر", th1: "المركز", th2: "المخزون", th3: "الحالة", th4: "سلسلة التبريد (IoT)", st_c: "حرج", st_s: "فائض", aiHead: "⚡ الذكاء الاصطناعي", al_h: "🚨 إنذار: القطاع 1", al_d: "نفاد المخزون قريباً.", al_a: "💡 الإجراء: 250 وحدة.", al_h2: "⚠️ تحذير IoT", al_d2: "فشل التبريد (>8°C).", al_a2: "💡 الإجراء: إرسال وحدة تبريد.", dBtn: "تفويض", speech: "يواجه القطاع 1 نقصًا وفشل تبريد IoT. الذكاء الاصطناعي يستجيب." }
#     };
#
#     function updateLanguage() {
#       const l = document.getElementById("langSelector").value;
#       const d = langDB[l];
#       document.getElementById("ui_sub").innerText = d.sub;
#       document.getElementById("ui_vBtn").innerText = d.vBtn;
#       document.getElementById("ui_dlBtn").innerText = d.dlBtn;
#       document.getElementById("ui_m1t").innerText = d.m1t; document.getElementById("ui_m1v").innerText = d.m1v;
#       document.getElementById("ui_m2t").innerText = d.m2t; document.getElementById("ui_m2v").innerText = d.m2v;
#       document.getElementById("ui_m3t").innerText = d.m3t; document.getElementById("ui_m3v").innerText = d.m3v;
#       document.getElementById("ui_m4t").innerText = d.m4t; document.getElementById("ui_m4v").innerText = d.m4v;
#       document.getElementById("ui_thead").innerText = d.th_head;
#       document.getElementById("th_1").innerText = d.th1; document.getElementById("th_2").innerText = d.th2; document.getElementById("th_3").innerText = d.th3; document.getElementById("th_4").innerText = d.th4;
#       document.getElementById("st_c1").innerText = d.st_c; document.getElementById("st_c2").innerText = d.st_c; document.getElementById("st_s1").innerText = d.st_s;
#       document.getElementById("ui_aiHead").innerText = d.aiHead;
#       document.getElementById("al_h").innerText = d.al_h; document.getElementById("al_d").innerText = d.al_d; document.getElementById("al_a").innerText = d.al_a;
#       document.getElementById("al_h2").innerText = d.al_h2; document.getElementById("al_d2").innerText = d.al_d2; document.getElementById("al_a2").innerText = d.al_a2;
#       document.getElementById("ui_dBtn").innerText = d.dBtn;
#       document.body.dir = (l === 'ar') ? 'rtl' : 'ltr';
#     }
#
#     function playAudioAssist() {
#       if (!('speechSynthesis' in window)) { alert("Audio Voice API not supported."); return; }
#       window.speechSynthesis.cancel();
#       const d = langDB[document.getElementById("langSelector").value];
#       const utterance = new SpeechSynthesisUtterance(d.speech);
#       utterance.lang = d.code; utterance.rate = 0.95;
#       const btnSpan = document.getElementById("ui_vBtn");
#       const orig = btnSpan.innerText; btnSpan.innerText = "...";
#       utterance.onend = () => { btnSpan.innerText = orig; };
#       utterance.onerror = () => { btnSpan.innerText = orig; };
#       window.speechSynthesis.speak(utterance);
#     }
#
#     function downloadReport() {
#       const csvData = "Facility Node,Stock (Paracetamol),Cold Chain Temp,Status\nPHC Sector 1,75 Units,12°C (Warning),Critical Risk\nPHC Sector 2,85 Units,5°C (Safe),Critical Risk\nPHC Sector 3,520 Units,4°C (Safe),Surplus Node\n\nGenerated by AuraHealth Global Grid (AES-256 Encrypted)";
#       const blob = new Blob([csvData], { type: 'text/csv' });
#       const url = window.URL.createObjectURL(blob);
#       const a = document.createElement('a');
#       a.setAttribute('href', url);
#       a.setAttribute('download', 'AuraHealth_Telemetry_Report.csv');
#       a.click();
#     }
#   </script>
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>AURAHEALTH GLOBAL | BRICS Enterprise</title>
#   <style>
#     :root {
#       --bg-base: #040814;
#       --surface: #0B1221;
#       --surface-border: rgba(255, 255, 255, 0.08);
#       --primary: #06B6D4;
#       --primary-glow: rgba(6, 182, 212, 0.3);
#       --danger: #EF4444;
#       --warning: #F59E0B;
#       --success: #10B981;
#       --text-main: #F8FAFC;
#       --text-muted: #94A3B8;
#     }
#
#     * { box-sizing: border-box; margin: 0; padding: 0; font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Helvetica, Arial, sans-serif; }
#     body { background-color: var(--bg-base); color: var(--text-main); padding: 24px; display: flex; flex-direction: column; gap: 24px; min-height: 100vh; }
#
#     /* Header & Branding */
# ...
